# %% [markdown]
# <a href="https://colab.research.google.com/github/JeetRoy97/Democracy-2.0/blob/main/primer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("/content/drive/MyDrive/Research/Other datasets/topic0.csv")

# %%
# !pip install git+https://github.com/allenai/longformer.git

# %%
temp = df['title'].tolist()

# %%
#listToStr = ' <doc-sep> '.join(map(str, temp[:30]))
listToStr = ' '.join(map(str, temp[:]))
listToStr = listToStr.replace('\n',' ')

# %%
listToStr
# Out:
# 'Under Income Tax, all medical related deductions to be clubbed with a much higher overall limit. House Rent Income and interest expense to be treated separately in the existing section. The deductions and exemptions related to Housing for Individuals are spread across many sections with varying limits. All deductions related to self-occupied housing - either owned or rented - should ideally be clubbed into a single Section with a higher limit to avoid discrimination based on nomenclature of earning / expense. Increase education spending So the government should not go on changing the fitment factor of central government staff salary and increase the salary of high salary earners in the Government, in the hope these people will drive consumption by purchasing more cars, house etc, which is completely wrong, making a few people more wealthy by increasing their salary for no valid reasons in the hope of creating demand in the economy is poor economics. Salaried people are the ones who 
# ...

# %%
# from transformers import AutoTokenizer
# from longformer import LongformerEncoderDecoderForConditionalGeneration
# from longformer import LongformerEncoderDecoderConfig
# device = 'cuda'
# model_path = "/content/drive/MyDrive/Research/Models/PRIMER"
# tokenizer = AutoTokenizer.from_pretrained(model_path)
# config = LongformerEncoderDecoderConfig.from_pretrained(model_path)
# model = LongformerEncoderDecoderForConditionalGeneration.from_pretrained(model_path, config=config).to(device)
# inputs_dict = tokenizer(listToStr, padding="max_length", max_length=1024, return_tensors="pt", truncation=True)
# input_ids = inputs_dict.input_ids.to(device)
# attention_mask = inputs_dict.attention_mask.to(device)w

# %%
# len(attention_mask[0])

# %%
# predicted_ids = model.generate(input_ids, attention_mask=attention_mask, max_length=256, min_length=0, num_beams=5, no_repeat_ngram_size=3)
# text = tokenizer.batch_decode(predicted_ids, skip_special_tokens=True)

# %%
# text

# %%
# temp

# %%
# !pip install bert-extractive-summarizer

# %%
# !pip install -U sentence-transformers

# %%
# !pip install spacy
# !pip install transformers # > 4.0.0
# !pip install neuralcoref

# !python -m spacy download en_core_web_md
# Out:
# ...
#      |████████████████████████████████| 96.4 MB 1.2 MB/s
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_md')

# %%
from summarizer.sbert import SBertSummarizer
from summarizer import Summarizer
from summarizer.text_processors.coreference_handler import CoreferenceHandler

#handler = CoreferenceHandler(greedyness=.4)
body = listToStr

model = SBertSummarizer('paraphrase-MiniLM-L6-v2')
result = model(body, ratio=0.05)
# Out:
# /usr/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: spacy.morphology.Morphology size changed, may indicate binary incompatibility. Expected 104 from C header, got 112 from PyObject
#   return f(*args, **kwds)
# /usr/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: spacy.vocab.Vocab size changed, may indicate binary incompatibility. Expected 96 from C header, got 104 from PyObject
#   return f(*args, **kwds)
# /usr/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: spacy.tokens.span.Span size changed, may indicate binary incompatibility. Expected 72 from C header, got 80 from PyObject
#   return f(*args, **kwds)

# %%
x = result.split('. ')
print(len(x))
# Out:
# 33

# %%
y = body.split('. ')
print(len(y))
# Out:
# 690

# %%
x
# Out:
# ['Under Income Tax, all medical related deductions to be clubbed with a much higher overall limit',
#  'All deductions related to self-occupied housing - either owned or rented - should ideally be clubbed into a single Section with a higher limit to avoid discrimination based on nomenclature of earning / expense',
#  '15) Legislation should be enacted to ensure that cell phone companies do not act against the government at any time 16) Steps should be taken to phase out cash flow in paper form 17) The intangible assets must be linked to the aadhar number 18) Its current status should be updated once a year in schools and higher education',
# ...
